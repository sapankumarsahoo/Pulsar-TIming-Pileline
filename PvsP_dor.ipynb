# %%
from numpy import *
import matplotlib.pyplot as plt
import pandas as pd
import psrqpy
from matplotlib import rcParams
from matplotlib import lines

# Your existing code for querying and plotting
query = psrqpy.QueryATNF(params=['P0', 'P1'])
fig = query.ppdot(showSNRs=True, showtypes='all')
mark = plt.scatter(0.0026008347856317, 1.6873E-20, color='red', label='')
mark = plt.scatter(0.00484275732280295, 6.065E-21, color='red', label='')

# Add the mark to the plot
fig.add_artist(mark)

# Add the line to the plot
x = [1, 4.2632901504]
y = [10 * (-21), 562.717 * 10 * (-15)]
plt.plot(x, y, color='red')
plt.xlabel('Period (s)',fontsize=20)
plt.ylabel('Period Derivative(s/s)',fontsize=20)

# Annotate the point
plt.annotate('J0248+4230', xy=[0.5, 0.5 * 10**-21])
plt.annotate('J1207-5050', xy=[0.5, 0.5 * 10**-22])

# Save the plot
plt.savefig('ppdot.png')
# Out:
# /home/ssahoo/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Avant Garde, Helvetica, Computer Modern Sans serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Avant Garde, Helvetica, Computer Modern Sans serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Avant Garde, Helvetica, Computer Modern Sans serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Avant Garde, Helvetica, Computer Modern Sans serif
# ...
